# %%
import numpy as np
from ThLd import ThLd

np.savetxt('tap.txt', np.array([[20,3],[0.2, 0.2]]))
exp1 = ThLd(data='ms')
exp1.alg()
exp1.estim()
# Out:
# generating ...
# chromosome 1/20 submited
# chromosome 2/20 submited
# chromosome 3/20 submited
# chromosome 4/20 submited
# chromosome 5/20 submited
# chromosome 6/20 submited
# chromosome 7/20 submited
# chromosome 8/20 submited
# chromosome 9/20 submited
# chromosome 10/20 submited
# chromosome 11/20 submited
# chromosome 12/20 submited
# chromosome 13/20 submited
# chromosome 14/20 submited
# chromosome 15/20 submited
# chromosome 16/20 submited
# chromosome 17/20 submited
# chromosome 18/20 submited
# chromosome 19/20 submited
# chromosome 20/20 submited
# generating done!
#
# chrom 1/20
# Bin: |##################################################| 100%, done for 0:00:58.649750
# FFT: |##################################################| 100%, nominator done for 0:01:04.645771
# FFT: |##################################################| 100%, denominator done for 0:00:00.655204
#
# chrom 2/20
# Bin: |##################################################| 100%, done for 0:00:59.511187
# ...

# %%
import numpy as np
from ThLd import ThLd
name = 'saved_data/'+'T1-'+str(0)+'_T2-'+str(10)+'_M1-'+str(0.2)+'_M2-'+str(0.2)+'.npy'
np.savetxt('tap.txt', np.array([[20,10],[0.2, 0.2]]))


exp = ThLd(data='ms')
exp.alg(coef=False)
exp.load(coef=name)
exp.estim()
# Out:
# generating ...
# chromosome 1/20 submited
# chromosome 2/20 submited
# chromosome 3/20 submited
# chromosome 4/20 submited
# chromosome 5/20 submited
# chromosome 6/20 submited
# chromosome 7/20 submited
# chromosome 8/20 submited
# chromosome 9/20 submited
# chromosome 10/20 submited
# chromosome 11/20 submited
# chromosome 12/20 submited
# chromosome 13/20 submited
# chromosome 14/20 submited
# chromosome 15/20 submited
# chromosome 16/20 submited
# chromosome 17/20 submited
# chromosome 18/20 submited
# chromosome 19/20 submited
# chromosome 20/20 submited
# generating done!
# deltas on chrom: <gen.Chromosome object at 0x129a24b20>
# deltas on chrom: <gen.Chromosome object at 0x12bcb2640>
# deltas on chrom: <gen.Chromosome object at 0x12bcb2610>
# deltas on chrom: <gen.Chromosome object at 0x12bcb2670>
# deltas on chrom: <gen.Chromosome object at 0x12bcb25e0>
# deltas on chrom: <gen.Chromosome object at 0x143a53370>
# deltas on chrom: <gen.Chromosome object at 0x143a539d0>
# ...
